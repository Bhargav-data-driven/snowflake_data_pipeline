# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bharg\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (2024.2.2)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="client_id", client_secret="client_secret")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza"
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '2YRe7HRKNRvXdJBp9nXFza'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data1 = sp.playlist_items(playlist_URI)
data1['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'type': 'album',
#   'album_type': 'album',
#   'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#   'id': '4yP0hdKOZPNshxUOjY0cZj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#     'width': 64}],
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#   'total_tracks': 14},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#    'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#    'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#    'name': 'The Weeknd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#  'disc_number': 1,
#  'track_number': 9,
#  'duration_ms': 200040,
#  'external_ids': {'isrc': 'USUG11904206'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'},
#  'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#  'id': '0VjIjW4GlUZAMYd2vXMi3b',
#  'name': 'Blinding Lights',
#  'popularity': 88,
#  'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#  'is_local': False}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 14

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '35s58BRTGAEWztPo9WqCIs',
#   'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#   'release_date': '2018-12-14',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'name': 'I Love You.',
#   'release_date': '2013-04-22',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '0G1ffjfFuTUTVjDrVdLimH',
#   'name': 'Views',
#   'release_date': '2016-05-13',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/0G1ffjfFuTUTVjDrVdLimH'},
#  {'album_id': '4bZJWQhHKJckFLJuYdvyX2',
#   'name': 'F*CK LOVE 3: OVER YOU',
#   'release_date': '2021-07-23',
#   'total_tracks': 29,
#   'url': 'https://open.spotify.com/album/4bZJWQhHKJckFLJuYdvyX2'},
#  {'album_id': '51s30K7a36ORx6AAaPBRRY',
#   'name': 'Evolve',
#   'release_date': '2017-06-23',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/51s30K7a36ORx6AAaPBRRY'},
#  {'album_id': '0KTj6k94XZh0c6IEMfxeWV',
#   'name': 'Dreamland (+ Bonus Levels)',
#   'release_date': '2020-08-06',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0KTj6k94XZh0c6IEMfxeWV'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '1AZjTOqvw2ZogWZxnDlhEN',
#   'name': 'Welcome To The Madhouse (Deluxe)',
#   'release_date': '2021-07-16',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/1AZjTOqvw2ZogWZxnDlhEN'},
#  {'album_id': '2sBB17RXTamvj7Ncps15AK',
#   'name': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#  {'album_id': '7oiJYvEJHsmYtrgviAVIBD',
#   'name': 'Back from the Edge',
#   'release_date': '2016-10-28',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/7oiJYvEJHsmYtrgviAVIBD'},
#  {'album_id': '22rp3PnM3q2mtTI0OGCzpq',
#   'name': 'Collage EP',
#   'release_date': '2016-11-04',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/22rp3PnM3q2mtTI0OGCzpq'},
#  {'album_id': '6trNtQUgC8cgbWcqoMYkOR',
#   'name': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6trNtQUgC8cgbWcqoMYkOR'},
#  {'album_id': '4JPguzRps3kuWDD5GS6oXr',
#   'name': 'Memories...Do Not Open',
#   'release_date': '2017-04-07',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4JPguzRps3kuWDD5GS6oXr'},
#  {'album_id': '5S9b8euumqMhQbMk0zzQdH',
#   'name': 'Dream Your Life Away (Special Edition)',
#   'release_date': '2014-09-08',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5S9b8euumqMhQbMk0zzQdH'},
#  {'album_id': '7xV2TzoaVc0ycW7fwBwAml',
#   'name': 'Fine Line',
#   'release_date': '2019-12-13',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7xV2TzoaVc0ycW7fwBwAml'},
#  {'album_id': '0xzScN8P3hQAz3BT3YYX5w',
#   'name': 'Shawn Mendes (Deluxe)',
#   'release_date': '2019-06-19',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/0xzScN8P3hQAz3BT3YYX5w'},
#  {'album_id': '7fJJK56U9fHixgO0HQkhtI',
#   'name': 'Future Nostalgia',
#   'release_date': '2020-03-27',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#  {'album_id': '04E0aLUdCHnhnnYrDDvcHq',
#   'name': 'Hozier',
#   'release_date': '2014-10-07',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/04E0aLUdCHnhnnYrDDvcHq'},
#  {'album_id': '2viWIVEItaDlFH2RXWKwS7',
#   'name': 'Goodbye & Good Riddance',
#   'release_date': '2018-05-23',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2viWIVEItaDlFH2RXWKwS7'},
#  {'album_id': '3oEqMQVxXfn2jGRaauU2iv',
#   'name': 'Long Way Down',
#   'release_date': '2013-09-17',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3oEqMQVxXfn2jGRaauU2iv'},
#  {'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'name': 'x (Deluxe Edition)',
#   'release_date': '2014-06-21',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '0G0vIGvVlJ3MtXunjqrbMY',
#   'name': 'Native (Deluxe)',
#   'release_date': '2013-03-26',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/0G0vIGvVlJ3MtXunjqrbMY'},
#  {'album_id': '1ATL5GLyefJaxhQzSPVrLX',
#   'name': 'Scorpion',
#   'release_date': '2018-06-29',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#  {'album_id': '4g1ZRSobMefqF6nelkgibi',
#   'name': "Hollywood's Bleeding",
#   'release_date': '2019-09-06',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4g1ZRSobMefqF6nelkgibi'},
#  {'album_id': '6X9k3hSsvQck2OfKYdBbXr',
#   'name': 'A Night At The Opera (Deluxe Remastered Version)',
#   'release_date': '1975-11-21',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6X9k3hSsvQck2OfKYdBbXr'},
#  {'album_id': '3yoNZlqerJnsnMN5EDwwBS',
#   'name': 'Strange Trails',
#   'release_date': '2015-04-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3yoNZlqerJnsnMN5EDwwBS'},
#  {'album_id': '0S0KGZnfBGSIssfF54WSJh',
#   'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#  {'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'name': 'x (Deluxe Edition)',
#   'release_date': '2014-06-21',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#  {'album_id': '76FXHQhTuT4QMIxfL09gX8',
#   'name': 'The Heist',
#   'release_date': '2012-10-09',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/76FXHQhTuT4QMIxfL09gX8'},
#  {'album_id': '4sLtOBOzn4s3GDUv3c5oJD',
#   'name': 'A Star Is Born Soundtrack',
#   'release_date': '2018-10-05',
#   'total_tracks': 34,
#   'url': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#  {'album_id': '42WVQWuf1teDysXiOupIZt',
#   'name': 'Birds In The Trap Sing McKnight',
#   'release_date': '2016-09-16',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/42WVQWuf1teDysXiOupIZt'},
#  {'album_id': '6Fr2rQkZ383FcMqFyT7yPr',
#   'name': 'Purpose (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#  {'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'name': 'Parachutes',
#   'release_date': '2000-07-10',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#  {'album_id': '51s30K7a36ORx6AAaPBRRY',
#   'name': 'Evolve',
#   'release_date': '2017-06-23',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/51s30K7a36ORx6AAaPBRRY'},
#  {'album_id': '4OTAx9un4e6NfoHuVRiOrC',
#   'name': 'Love In The Future (Expanded Edition)',
#   'release_date': '2013-08-30',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/4OTAx9un4e6NfoHuVRiOrC'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '37qAVEAZSyRTVFvVRHcwOa',
#   'name': 'Wake Me Up',
#   'release_date': '2013-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/37qAVEAZSyRTVFvVRHcwOa'},
#  {'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': '28ZKQMoNBB0etKXZ97G2SN',
#   'name': 'Beauty Behind The Madness',
#   'release_date': '2015-08-28',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/28ZKQMoNBB0etKXZ97G2SN'},
#  {'album_id': '3cQO7jp5S9qLBoIVtbkSM1',
#   'name': 'Blurryface',
#   'release_date': '2015-05-15',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3cQO7jp5S9qLBoIVtbkSM1'},
#  {'album_id': '6htgf3qv7vGcsdxLCDxKp8',
#   'name': 'Night Visions',
#   'release_date': '2012-09-04',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6htgf3qv7vGcsdxLCDxKp8'},
#  {'album_id': '7viNUmZZ8ztn2UB4XB3jIL',
#   'name': '2014 Forest Hills Drive',
#   'release_date': '2014-12-09',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/7viNUmZZ8ztn2UB4XB3jIL'},
#  {'album_id': '2sRnJq6dfXdqhIflBk0ve1',
#   'name': 'All the Little Lights',
#   'release_date': '2012-06-29',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2sRnJq6dfXdqhIflBk0ve1'},
#  {'album_id': '2fYhqwDWXjbpjaIJPEfKFw',
#   'name': 'thank u, next',
#   'release_date': '2019-02-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#  {'album_id': '4eLPsYPBmXABThSJ821sqY',
#   'name': 'DAMN.',
#   'release_date': '2017-04-14',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4eLPsYPBmXABThSJ821sqY'},
#  {'album_id': '4undIeGmofnAYKhnDclN1w',
#   'name': 'Hot Fuss',
#   'release_date': '2004-06-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4undIeGmofnAYKhnDclN1w'},
#  {'album_id': '1CEODgTmTwLyabvwd7HBty',
#   'name': 'Viva La Vida or Death and All His Friends',
#   'release_date': '2008-06-06',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#  {'album_id': '5qENHeCSlwWpEzb25peRmQ',
#   'name': 'Curtain Call: The Hits (Deluxe Edition)',
#   'release_date': '2005-12-06',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/5qENHeCSlwWpEzb25peRmQ'},
#  {'album_id': '5bU1XKYxHhEwukllT20xtk',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5bU1XKYxHhEwukllT20xtk'},
#  {'album_id': '2cWBwpqMsDJC1ZUwz813lo',
#   'name': 'The Eminem Show',
#   'release_date': '2002-05-26',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#  {'album_id': '7GEzhoTiqcPYkOprWQu581',
#   'name': 'One Kiss (with Dua Lipa)',
#   'release_date': '2018-04-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7GEzhoTiqcPYkOprWQu581'},
#  {'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'name': 'SOUR',
#   'release_date': '2021-05-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#  {'album_id': '2Ti79nwTsont5ZHfdxIzAm',
#   'name': '?',
#   'release_date': '2018-03-16',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#  {'album_id': '2AJaA0is5qbaqFy77tPl7B',
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2016-09-23',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2AJaA0is5qbaqFy77tPl7B'},
#  {'album_id': '58ufpQsJ1DS5kq4hhzQDiI',
#   'name': 'Unorthodox Jukebox',
#   'release_date': '2012-12-07',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/58ufpQsJ1DS5kq4hhzQDiI'},
#  {'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'name': 'SOUR',
#   'release_date': '2021-05-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#  {'album_id': '5VdyJkLe3yvOs0l4xXbWp0',
#   'name': '17',
#   'release_date': '2017-08-25',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5VdyJkLe3yvOs0l4xXbWp0'},
#  {'album_id': '1uyf3l2d4XYwiEqAb7t7fX',
#   'name': 'Doo-Wops & Hooligans',
#   'release_date': '2010-05-11',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#  {'album_id': '02sEJTj1sye1JaqxqpcSCp',
#   'name': 'Encore',
#   'release_date': '2016-08-05',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/02sEJTj1sye1JaqxqpcSCp'},
#  {'album_id': '78EicdHZr5XBWD7llEZ1Jh',
#   'name': 'Happier',
#   'release_date': '2018-08-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/78EicdHZr5XBWD7llEZ1Jh'},
#  {'album_id': '4c2p3TdN7NcQfCXyueCNnC',
#   'name': 'Jungle Rules',
#   'release_date': '2017-07-14',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4c2p3TdN7NcQfCXyueCNnC'},
#  {'album_id': '41GuZcammIkupMPKH2OJ6I',
#   'name': 'ASTROWORLD',
#   'release_date': '2018-08-03',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#  {'album_id': '733e1ZfktLSwj96X5rsMeE',
#   'name': 'Luv Is Rage 2',
#   'release_date': '2017-08-25',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/733e1ZfktLSwj96X5rsMeE'},
#  {'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'name': 'Endless Summer Vacation',
#   'release_date': '2023-03-10',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '4PgleR09JVnm3zY1fW3XBA',
#   'name': '24K Magic',
#   'release_date': '2016-11-17',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4PgleR09JVnm3zY1fW3XBA'},
#  {'album_id': '5W9OT0a5iZlBr83a9WMKFY',
#   'name': 'Synchronicity (Remastered 2003)',
#   'release_date': '1983-06-17',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5W9OT0a5iZlBr83a9WMKFY'},
#  {'album_id': '6hPkbAV3ZXpGZBGUvL6jVM',
#   'name': 'Hybrid Theory (Bonus Edition)',
#   'release_date': '2000-10-24',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6hPkbAV3ZXpGZBGUvL6jVM'},
#  {'album_id': '6Fr2rQkZ383FcMqFyT7yPr',
#   'name': 'Purpose (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#  {'album_id': '4DOcG4A40Wf3q2vPNGQwQg',
#   'name': 'Peace Is The Mission',
#   'release_date': '2015-06-01',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4DOcG4A40Wf3q2vPNGQwQg'},
#  {'album_id': '01sfgrNbnnPUEyz6GZYlt9',
#   'name': 'Dua Lipa (Deluxe)',
#   'release_date': '2017-06-02',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/01sfgrNbnnPUEyz6GZYlt9'},
#  {'album_id': '7KBjLhk3IM27k3ry4vBk3i',
#   'name': 'Unorthodox Jukebox',
#   'release_date': '2012-12-10',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7KBjLhk3IM27k3ry4vBk3i'},
#  {'album_id': '5lKlFlReHOLShQKyRv6AL9',
#   'name': 'Future Nostalgia',
#   'release_date': '2020-03-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#  {'album_id': '3wBabo4pmzsYjALMSKY7Iq',
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2017-04-20',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3wBabo4pmzsYjALMSKY7Iq'},
#  {'album_id': '3XftSbguntyRTBQaGItmfK',
#   'name': 'The Thrill Of It All (Special Edition)',
#   'release_date': '2017-11-03',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3XftSbguntyRTBQaGItmfK'},
#  {'album_id': '08jWgM4vSkTose4blKBWov',
#   'name': 'In The Lonely Hour',
#   'release_date': '2014-05-26',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/08jWgM4vSkTose4blKBWov'},
#  {'album_id': '7wHczdY0ek3FHnfVhk10om',
#   'name': 'The Lockdown Sessions',
#   'release_date': '2021-10-22',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/7wHczdY0ek3FHnfVhk10om'},
#  {'album_id': '2vD3zSQr8hNlg0obNel4TE',
#   'name': 'Camila',
#   'release_date': '2018-01-12',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2vD3zSQr8hNlg0obNel4TE'},
#  {'album_id': '2guirTSEqLizK7j9i1MTTZ',
#   'name': 'Nevermind (Remastered)',
#   'release_date': '1991-09-26',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#  {'album_id': '68enXe5XcJdciSDAZr0Alr',
#   'name': 'Manic',
#   'release_date': '2020-01-17',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/68enXe5XcJdciSDAZr0Alr'},
#  {'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '6ozp33PI3p9AdddB6ZL3xQ',
#   'name': "(What's The Story) Morning Glory? (Deluxe Edition) [Remastered]",
#   'release_date': '1995-10-02',
#   'total_tracks': 40,
#   'url': 'https://open.spotify.com/album/6ozp33PI3p9AdddB6ZL3xQ'},
#  {'album_id': '21HMAUrbbYSj9NiPPlGumy',
#   'name': 'Jazz (Deluxe Remastered Version)',
#   'release_date': '1978-11-10',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/21HMAUrbbYSj9NiPPlGumy'},
#  {'album_id': '1pCA38N6MkLlthXtAOvZTU',
#   'name': 'JORDI (Deluxe)',
#   'release_date': '2021-06-11',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1pCA38N6MkLlthXtAOvZTU'},
#  {'album_id': '43wpzak9OmQfrjyksuGwp0',
#   'name': 'Escape (Bonus Track Version)',
#   'release_date': '1981',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/43wpzak9OmQfrjyksuGwp0'},
#  {'album_id': '3vLaOYCNCzngDf8QdBg2V1',
#   'name': 'Uptown Special',
#   'release_date': '2015-01-12',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/3vLaOYCNCzngDf8QdBg2V1'},
#  {'album_id': '6pOiDiuDQqrmo5DbG0ZubR',
#   'name': 'MONTERO',
#   'release_date': '2021-09-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6pOiDiuDQqrmo5DbG0ZubR'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '1ER3B6zev5JEAaqhnyyfbf',
#   'name': 'Hunting High and Low',
#   'release_date': '1985-06-01',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1ER3B6zev5JEAaqhnyyfbf'},
#  {'album_id': '2d9BCZeAAhiZWPpbX9aPCW',
#   'name': 'EL ÚLTIMO TOUR DEL MUNDO',
#   'release_date': '2020-11-27',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2d9BCZeAAhiZWPpbX9aPCW'},
#  {'album_id': '5s0rmjP8XOPhP6HhqOhuyC',
#   'name': 'Stoney (Deluxe)',
#   'release_date': '2016-12-09',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#  {'album_id': '2cWBwpqMsDJC1ZUwz813lo',
#   'name': 'The Eminem Show',
#   'release_date': '2002-05-26',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#  {'album_id': '1azUkThwd2HfUDdeNeT147',
#   'name': '21',
#   'release_date': '2011-01-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#  {'album_id': '1Tz3Ai1guEFf4hV3d9i17K',
#   'name': 'At Night, Alone.',
#   'release_date': '2016-05-06',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1Tz3Ai1guEFf4hV3d9i17K'},
#  {'album_id': '0RHX9XECH8IVI3LNgWDpmQ',
#   'name': 'A Rush of Blood to the Head',
#   'release_date': '2002-08-27',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/0RHX9XECH8IVI3LNgWDpmQ'}]

# %% [markdown]
# ## artist_id = data['items'][99]['track']['artists'][0]['id']

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artist_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'artist_name': 'Swae Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'artist_name': 'The Neighbourhood',
#   'external_url': 'https://api.spotify.com/v1/artists/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '3tVQdUvClmAT7URs9V3rsp',
#   'artist_name': 'Wizkid',
#   'external_url': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp'},
#  {'artist_id': '6TK7fjRPdy2GW2pJzNF23L',
#   'artist_name': 'Kyla',
#   'external_url': 'https://api.spotify.com/v1/artists/6TK7fjRPdy2GW2pJzNF23L'},
#  {'artist_id': '2tIP7SsRs7vjIcLrU85W8J',
#   'artist_name': 'The Kid LAROI',
#   'external_url': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '4yvcSjfu4PC0CYQyLy4wSq',
#   'artist_name': 'Glass Animals',
#   'external_url': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '2NjfBq1NflQcKSeiDooVjY',
#   'artist_name': 'Tones And I',
#   'external_url': 'https://api.spotify.com/v1/artists/2NjfBq1NflQcKSeiDooVjY'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '6LuN9FCkKOj5PcnpouEgny',
#   'artist_name': 'Khalid',
#   'external_url': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '69GGBxA162lTqCwzJG5jLp',
#   'artist_name': 'The Chainsmokers',
#   'external_url': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp'},
#  {'artist_id': '26VFTg2z8YR0cCuwLzESi2',
#   'artist_name': 'Halsey',
#   'external_url': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '69GGBxA162lTqCwzJG5jLp',
#   'artist_name': 'The Chainsmokers',
#   'external_url': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '10exVja0key0uqUkk6LJRT',
#   'artist_name': 'Vance Joy',
#   'external_url': 'https://api.spotify.com/v1/artists/10exVja0key0uqUkk6LJRT'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '4nDoRrQiYLoBzwC5BhVJzF',
#   'artist_name': 'Camila Cabello',
#   'external_url': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'external_url': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '4MCBfE4596Uoi2O4DtmEMz',
#   'artist_name': 'Juice WRLD',
#   'external_url': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz'},
#  {'artist_id': '2txHhyCwHjUEpJjWrEyqyX',
#   'artist_name': 'Tom Odell',
#   'external_url': 'https://api.spotify.com/v1/artists/2txHhyCwHjUEpJjWrEyqyX'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'artist_name': 'OneRepublic',
#   'external_url': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '1dfeR4HaWDbWqFHLkxsg1d',
#   'artist_name': 'Queen',
#   'external_url': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d'},
#  {'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25',
#   'artist_name': 'Lord Huron',
#   'external_url': 'https://api.spotify.com/v1/artists/6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '3JhNCzhSMTxs9WLGJJxWOY',
#   'artist_name': 'Macklemore',
#   'external_url': 'https://api.spotify.com/v1/artists/3JhNCzhSMTxs9WLGJJxWOY'},
#  {'artist_id': '4myTppRgh0rojLxx8RycOp',
#   'artist_name': 'Ryan Lewis',
#   'external_url': 'https://api.spotify.com/v1/artists/4myTppRgh0rojLxx8RycOp'},
#  {'artist_id': '6WLvgbfYXQPO396oJEYCsi',
#   'artist_name': 'Macklemore & Ryan Lewis',
#   'external_url': 'https://api.spotify.com/v1/artists/6WLvgbfYXQPO396oJEYCsi'},
#  {'artist_id': '4e0nWw2r4BoQSKPQ2zpU13',
#   'artist_name': 'Ray Dalton',
#   'external_url': 'https://api.spotify.com/v1/artists/4e0nWw2r4BoQSKPQ2zpU13'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '4VIvfOurcf0vuLRxLkGnIG',
#   'artist_name': 'Bradley Cooper',
#   'external_url': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '5y2Xq6xcjJb2jVM54GHK3t',
#   'artist_name': 'John Legend',
#   'external_url': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1vCWHaC5f2uS3yhpwWbIA6',
#   'artist_name': 'Avicii',
#   'external_url': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '3YQKmKGau1PzlVlkL1iodx',
#   'artist_name': 'Twenty One Pilots',
#   'external_url': 'https://api.spotify.com/v1/artists/3YQKmKGau1PzlVlkL1iodx'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'artist_name': 'J. Cole',
#   'external_url': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5'},
#  {'artist_id': '0gadJ2b9A4SKsB1RFkBb66',
#   'artist_name': 'Passenger',
#   'external_url': 'https://api.spotify.com/v1/artists/0gadJ2b9A4SKsB1RFkBb66'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '0C0XlULifJtAgn6ZNCW2eu',
#   'artist_name': 'The Killers',
#   'external_url': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'artist_name': 'Eminem',
#   'external_url': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'artist_name': 'Eminem',
#   'external_url': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR'},
#  {'artist_id': '7CajNmpbOovFoOoasH2HaY',
#   'artist_name': 'Calvin Harris',
#   'external_url': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '15UsOTVnJzReFVN1VCnxy4',
#   'artist_name': 'XXXTENTACION',
#   'external_url': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '15UsOTVnJzReFVN1VCnxy4',
#   'artist_name': 'XXXTENTACION',
#   'external_url': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '540vIaP2JwjQb9dm3aArA4',
#   'artist_name': 'DJ Snake',
#   'external_url': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '64KEffDW9EtZ1y2vBYgq8T',
#   'artist_name': 'Marshmello',
#   'external_url': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T'},
#  {'artist_id': '7EQ0qTo7fWT7DPxmxtSYEc',
#   'artist_name': 'Bastille',
#   'external_url': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc'},
#  {'artist_id': '6vXTefBL93Dj5IqAWq6OTv',
#   'artist_name': 'French Montana',
#   'external_url': 'https://api.spotify.com/v1/artists/6vXTefBL93Dj5IqAWq6OTv'},
#  {'artist_id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'artist_name': 'Swae Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '4O15NlyKLIASxsJ0PrXPfz',
#   'artist_name': 'Lil Uzi Vert',
#   'external_url': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '5NGO30tJxFlKixkPSgXcFE',
#   'artist_name': 'The Police',
#   'external_url': 'https://api.spotify.com/v1/artists/5NGO30tJxFlKixkPSgXcFE'},
#  {'artist_id': '6XyY86QOPPrYVGvF9ch6wz',
#   'artist_name': 'Linkin Park',
#   'external_url': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '738wLrAtLtCtFOLvQBXOXp',
#   'artist_name': 'Major Lazer',
#   'external_url': 'https://api.spotify.com/v1/artists/738wLrAtLtCtFOLvQBXOXp'},
#  {'artist_id': '0bdfiayQAKewqEvaU6rXCv',
#   'artist_name': 'MØ',
#   'external_url': 'https://api.spotify.com/v1/artists/0bdfiayQAKewqEvaU6rXCv'},
#  {'artist_id': '540vIaP2JwjQb9dm3aArA4',
#   'artist_name': 'DJ Snake',
#   'external_url': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '4r63FhuTkUYltbVAg5TQnk',
#   'artist_name': 'DaBaby',
#   'external_url': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '2wY79sveU1sp5g7SokKOiI',
#   'artist_name': 'Sam Smith',
#   'external_url': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI'},
#  {'artist_id': '2wY79sveU1sp5g7SokKOiI',
#   'artist_name': 'Sam Smith',
#   'external_url': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI'},
#  {'artist_id': '3PhoLpVuITZKcymswpck5b',
#   'artist_name': 'Elton John',
#   'external_url': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '6n28c9qs9hNGriNa72b26u',
#   'artist_name': 'PNAU',
#   'external_url': 'https://api.spotify.com/v1/artists/6n28c9qs9hNGriNa72b26u'},
#  {'artist_id': '4nDoRrQiYLoBzwC5BhVJzF',
#   'artist_name': 'Camila Cabello',
#   'external_url': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF'},
#  {'artist_id': '50co4Is1HCEo8bhOyUWKpn',
#   'artist_name': 'Young Thug',
#   'external_url': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn'},
#  {'artist_id': '6olE6TJLqED3rqDCT0FyPh',
#   'artist_name': 'Nirvana',
#   'external_url': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh'},
#  {'artist_id': '26VFTg2z8YR0cCuwLzESi2',
#   'artist_name': 'Halsey',
#   'external_url': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '2DaxqgrOhkeH0fpeiQq2f4',
#   'artist_name': 'Oasis',
#   'external_url': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4'},
#  {'artist_id': '1dfeR4HaWDbWqFHLkxsg1d',
#   'artist_name': 'Queen',
#   'external_url': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d'},
#  {'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'external_url': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '3hv9jJF3adDNsBSIQDqcjp',
#   'artist_name': 'Mark Ronson',
#   'external_url': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '7jVv8c5Fj3E9VhNjxT4snq',
#   'artist_name': 'Lil Nas X',
#   'external_url': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq'},
#  {'artist_id': '2LIk90788K0zvyj2JJVwkJ',
#   'artist_name': 'Jack Harlow',
#   'external_url': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2jzc5TC5TVFLXQlBNiIUzE',
#   'artist_name': 'a-ha',
#   'external_url': 'https://api.spotify.com/v1/artists/2jzc5TC5TVFLXQlBNiIUzE'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6nVcHLIgY5pE2YCl8ubca1',
#   'artist_name': 'JHAYCO',
#   'external_url': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '0VRj0yCOv2FXJNP47XQnx5',
#   'artist_name': 'Quavo',
#   'external_url': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5'},
#  {'artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'artist_name': 'Eminem',
#   'external_url': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR'},
#  {'artist_id': '1Oa0bMld0A3u5OTYfMzp5h',
#   'artist_name': 'Nate Dogg',
#   'external_url': 'https://api.spotify.com/v1/artists/1Oa0bMld0A3u5OTYfMzp5h'},
#  {'artist_id': '4dpARuHxo51G3z768sgnrY',
#   'artist_name': 'Adele',
#   'external_url': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY'},
#  {'artist_id': '2KsP6tYLJlTBvSUxnwlVWa',
#   'artist_name': 'Mike Posner',
#   'external_url': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa'},
#  {'artist_id': '5iNrZmtVMtYev5M9yoWpEq',
#   'artist_name': 'Seeb',
#   'external_url': 'https://api.spotify.com/v1/artists/5iNrZmtVMtYev5M9yoWpEq'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'}]

# %%
data['items'][0]['added_at']
# Out:
# '2020-03-20T04:54:59Z'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration_ms': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 88,
#   'song_added': '2020-03-20T04:54:59Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration_ms': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 87,
#   'song_added': '2017-06-09T00:39:52Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
#   'song_name': 'Someone You Loved',
#   'duration_ms': 182160,
#   'url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf',
#   'popularity': 85,
#   'song_added': '2019-08-31T17:45:01Z',
#   'album_id': '5658aM19fA3JVwTK6eQX70',
#   'artist_id': '4GNC7GD6oZMSxPGyXy4MNB'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'duration_ms': 167303,
#   'url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'popularity': 87,
#   'song_added': '2022-08-30T23:21:01Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '7MXVkk9YMctZqd1Srtv4MB',
#   'song_name': 'Starboy',
#   'duration_ms': 230453,
#   'url': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB',
#   'popularity': 88,
#   'song_added': '2017-06-09T00:44:54Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '3KkXRkHbMCARz0aVfEt68P',
#   'song_name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'duration_ms': 158040,
#   'url': 'https://open.spotify.com/track/3KkXRkHbMCARz0aVfEt68P',
#   'popularity': 81,
#   'song_added': '2019-08-31T17:18:20Z',
#   'album_id': '35s58BRTGAEWztPo9WqCIs',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_name': 'Sweater Weather',
#   'duration_ms': 240400,
#   'url': 'https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6',
#   'popularity': 90,
#   'song_added': '2017-12-08T15:15:10Z',
#   'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'artist_id': '77SW9BnxLY8rJ0RciFqkHh'},
#  {'song_id': '12VWzyPDBCc8fqeWCAfNwR',
#   'song_name': 'One Dance',
#   'duration_ms': 173986,
#   'url': 'https://open.spotify.com/track/12VWzyPDBCc8fqeWCAfNwR',
#   'popularity': 2,
#   'song_added': '2016-06-27T04:39:48Z',
#   'album_id': '0G1ffjfFuTUTVjDrVdLimH',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '5PjdY0CKGZdEuoNab3yDmX',
#   'song_name': 'STAY (with Justin Bieber)',
#   'duration_ms': 141805,
#   'url': 'https://open.spotify.com/track/5PjdY0CKGZdEuoNab3yDmX',
#   'popularity': 10,
#   'song_added': '2021-08-08T01:20:27Z',
#   'album_id': '4bZJWQhHKJckFLJuYdvyX2',
#   'artist_id': '2tIP7SsRs7vjIcLrU85W8J'},
#  {'song_id': '1NtIMM4N0cFa1dNzN15chl',
#   'song_name': 'Believer',
#   'duration_ms': 204346,
#   'url': 'https://open.spotify.com/track/1NtIMM4N0cFa1dNzN15chl',
#   'popularity': 2,
#   'song_added': '2018-01-04T16:46:17Z',
#   'album_id': '51s30K7a36ORx6AAaPBRRY',
#   'artist_id': '53XhwfbYqKCa1cC15pYq2q'},
#  {'song_id': '02MWAaffLxlfxAUY7c5dvx',
#   'song_name': 'Heat Waves',
#   'duration_ms': 238805,
#   'url': 'https://open.spotify.com/track/02MWAaffLxlfxAUY7c5dvx',
#   'popularity': 16,
#   'song_added': '2021-08-26T04:38:10Z',
#   'album_id': '0KTj6k94XZh0c6IEMfxeWV',
#   'artist_id': '4yvcSjfu4PC0CYQyLy4wSq'},
#  {'song_id': '0tgVpDi06FyKpA1z0VMD4v',
#   'song_name': 'Perfect',
#   'duration_ms': 263400,
#   'url': 'https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v',
#   'popularity': 88,
#   'song_added': '2018-01-04T16:45:18Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '2N8m6CYs74qQO4mjVcXO30',
#   'song_name': 'Dance Monkey',
#   'duration_ms': 209438,
#   'url': 'https://open.spotify.com/track/2N8m6CYs74qQO4mjVcXO30',
#   'popularity': 73,
#   'song_added': '2022-05-13T18:52:31Z',
#   'album_id': '1AZjTOqvw2ZogWZxnDlhEN',
#   'artist_id': '2NjfBq1NflQcKSeiDooVjY'},
#  {'song_id': '0u2P5u6lvoDfwTYjAADbn4',
#   'song_name': 'lovely (with Khalid)',
#   'duration_ms': 200185,
#   'url': 'https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4',
#   'popularity': 87,
#   'song_added': '2019-08-31T17:41:46Z',
#   'album_id': '2sBB17RXTamvj7Ncps15AK',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5uCax9HTNlzGybIStD3vDh',
#   'song_name': "Say You Won't Let Go",
#   'duration_ms': 211466,
#   'url': 'https://open.spotify.com/track/5uCax9HTNlzGybIStD3vDh',
#   'popularity': 83,
#   'song_added': '2017-06-17T22:39:02Z',
#   'album_id': '7oiJYvEJHsmYtrgviAVIBD',
#   'artist_id': '4IWBUUAFIplrNtaOHcJPRM'},
#  {'song_id': '7crMiinWx373rNBZBaVske',
#   'song_name': 'Closer',
#   'duration_ms': 245506,
#   'url': 'https://open.spotify.com/track/7crMiinWx373rNBZBaVske',
#   'popularity': 52,
#   'song_added': '2017-06-09T00:39:17Z',
#   'album_id': '22rp3PnM3q2mtTI0OGCzpq',
#   'artist_id': '69GGBxA162lTqCwzJG5jLp'},
#  {'song_id': '0e7ipj03S05BNilyu5bRzt',
#   'song_name': 'rockstar (feat. 21 Savage)',
#   'duration_ms': 218146,
#   'url': 'https://open.spotify.com/track/0e7ipj03S05BNilyu5bRzt',
#   'popularity': 81,
#   'song_added': '2020-03-28T02:36:06Z',
#   'album_id': '6trNtQUgC8cgbWcqoMYkOR',
#   'artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '6RUKPb4LETWmmr3iAEQktW',
#   'song_name': 'Something Just Like This',
#   'duration_ms': 247160,
#   'url': 'https://open.spotify.com/track/6RUKPb4LETWmmr3iAEQktW',
#   'popularity': 88,
#   'song_added': '2019-11-08T23:23:09Z',
#   'album_id': '4JPguzRps3kuWDD5GS6oXr',
#   'artist_id': '69GGBxA162lTqCwzJG5jLp'},
#  {'song_id': '3JvrhDOgAt6p7K8mDyZwRd',
#   'song_name': 'Riptide',
#   'duration_ms': 204280,
#   'url': 'https://open.spotify.com/track/3JvrhDOgAt6p7K8mDyZwRd',
#   'popularity': 23,
#   'song_added': '2016-09-29T04:06:03Z',
#   'album_id': '5S9b8euumqMhQbMk0zzQdH',
#   'artist_id': '10exVja0key0uqUkk6LJRT'},
#  {'song_id': '6UelLqGlWMcVH1E5c4H7lY',
#   'song_name': 'Watermelon Sugar',
#   'duration_ms': 174000,
#   'url': 'https://open.spotify.com/track/6UelLqGlWMcVH1E5c4H7lY',
#   'popularity': 83,
#   'song_added': '2020-07-16T17:42:31Z',
#   'album_id': '7xV2TzoaVc0ycW7fwBwAml',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '6v3KW9xbzN5yKLt9YKDYA2',
#   'song_name': 'Señorita',
#   'duration_ms': 190799,
#   'url': 'https://open.spotify.com/track/6v3KW9xbzN5yKLt9YKDYA2',
#   'popularity': 78,
#   'song_added': '2019-08-31T17:42:24Z',
#   'album_id': '0xzScN8P3hQAz3BT3YYX5w',
#   'artist_id': '7n2wHs1TKAczGzO7Dd2rGr'},
#  {'song_id': '3PfIrDoz19wz7qK7tYeu62',
#   'song_name': "Don't Start Now",
#   'duration_ms': 183290,
#   'url': 'https://open.spotify.com/track/3PfIrDoz19wz7qK7tYeu62',
#   'popularity': 81,
#   'song_added': '2020-07-20T06:32:09Z',
#   'album_id': '7fJJK56U9fHixgO0HQkhtI',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '0aOluBqXYd0rFSCsgDyAWX',
#   'song_name': 'Take Me to Church',
#   'duration_ms': 241693,
#   'url': 'https://open.spotify.com/track/0aOluBqXYd0rFSCsgDyAWX',
#   'popularity': 61,
#   'song_added': '2014-11-15T03:42:15Z',
#   'album_id': '04E0aLUdCHnhnnYrDDvcHq',
#   'artist_id': '2FXC3k01G6Gw61bmprjgqS'},
#  {'song_id': '0s3nnoMeVWz3989MkNQiRf',
#   'song_name': 'Lucid Dreams',
#   'duration_ms': 239835,
#   'url': 'https://open.spotify.com/track/0s3nnoMeVWz3989MkNQiRf',
#   'popularity': 2,
#   'song_added': '2018-08-06T01:03:28Z',
#   'album_id': '2viWIVEItaDlFH2RXWKwS7',
#   'artist_id': '4MCBfE4596Uoi2O4DtmEMz'},
#  {'song_id': '7otCGmgp9h4CsR2LhwB6gt',
#   'song_name': 'Another Love',
#   'duration_ms': 244360,
#   'url': 'https://open.spotify.com/track/7otCGmgp9h4CsR2LhwB6gt',
#   'popularity': 64,
#   'song_added': '2022-08-30T23:16:16Z',
#   'album_id': '3oEqMQVxXfn2jGRaauU2iv',
#   'artist_id': '2txHhyCwHjUEpJjWrEyqyX'},
#  {'song_id': '1HNkqx9Ahdgi1Ixy2xkKkL',
#   'song_name': 'Photograph',
#   'duration_ms': 258986,
#   'url': 'https://open.spotify.com/track/1HNkqx9Ahdgi1Ixy2xkKkL',
#   'popularity': 86,
#   'song_added': '2015-11-12T15:51:28Z',
#   'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'duration_ms': 183956,
#   'url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'popularity': 91,
#   'song_added': '2022-12-02T08:24:49Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '1fh2TfUOtOoXEE8qQynYEC',
#   'song_name': 'Counting Stars',
#   'duration_ms': 257279,
#   'url': 'https://open.spotify.com/track/1fh2TfUOtOoXEE8qQynYEC',
#   'popularity': 0,
#   'song_added': '2013-12-08T20:01:05Z',
#   'album_id': '0G0vIGvVlJ3MtXunjqrbMY',
#   'artist_id': '5Pwc4xIPtQLFEnJriah9YJ'},
#  {'song_id': '6DCZcSspjsKoFjzjrWoCdn',
#   'song_name': "God's Plan",
#   'duration_ms': 198973,
#   'url': 'https://open.spotify.com/track/6DCZcSspjsKoFjzjrWoCdn',
#   'popularity': 82,
#   'song_added': '2019-11-08T23:22:39Z',
#   'album_id': '1ATL5GLyefJaxhQzSPVrLX',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '21jGcNKet2qwijlDFuPiPb',
#   'song_name': 'Circles',
#   'duration_ms': 215280,
#   'url': 'https://open.spotify.com/track/21jGcNKet2qwijlDFuPiPb',
#   'popularity': 85,
#   'song_added': '2019-11-01T04:09:44Z',
#   'album_id': '4g1ZRSobMefqF6nelkgibi',
#   'artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '7tFiyTwD0nx5a1eklYtX2J',
#   'song_name': 'Bohemian Rhapsody - Remastered 2011',
#   'duration_ms': 354320,
#   'url': 'https://open.spotify.com/track/7tFiyTwD0nx5a1eklYtX2J',
#   'popularity': 71,
#   'song_added': '2019-02-08T06:54:01Z',
#   'album_id': '6X9k3hSsvQck2OfKYdBbXr',
#   'artist_id': '1dfeR4HaWDbWqFHLkxsg1d'},
#  {'song_id': '0QZ5yyl6B6utIWkxeBDxQN',
#   'song_name': 'The Night We Met',
#   'duration_ms': 208211,
#   'url': 'https://open.spotify.com/track/0QZ5yyl6B6utIWkxeBDxQN',
#   'popularity': 78,
#   'song_added': '2022-07-26T04:57:27Z',
#   'album_id': '3yoNZlqerJnsnMN5EDwwBS',
#   'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'song_id': '2Fxmhks0bxGSBdJ92vM42m',
#   'song_name': 'bad guy',
#   'duration_ms': 194087,
#   'url': 'https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m',
#   'popularity': 81,
#   'song_added': '2019-08-31T17:41:50Z',
#   'album_id': '0S0KGZnfBGSIssfF54WSJh',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '34gCuhDGsG4bRPIf9bb02f',
#   'song_name': 'Thinking out Loud',
#   'duration_ms': 281560,
#   'url': 'https://open.spotify.com/track/34gCuhDGsG4bRPIf9bb02f',
#   'popularity': 82,
#   'song_added': '2014-11-24T21:44:23Z',
#   'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '3bidbhpOYeV4knp8AIu8Xn',
#   'song_name': "Can't Hold Us (feat. Ray Dalton)",
#   'duration_ms': 258342,
#   'url': 'https://open.spotify.com/track/3bidbhpOYeV4knp8AIu8Xn',
#   'popularity': 79,
#   'song_added': '2013-12-08T14:46:10Z',
#   'album_id': '76FXHQhTuT4QMIxfL09gX8',
#   'artist_id': '6WLvgbfYXQPO396oJEYCsi'},
#  {'song_id': '2VxeLyX666F8uXCJ0dZF8B',
#   'song_name': 'Shallow',
#   'duration_ms': 215733,
#   'url': 'https://open.spotify.com/track/2VxeLyX666F8uXCJ0dZF8B',
#   'popularity': 83,
#   'song_added': '2019-08-31T17:32:45Z',
#   'album_id': '4sLtOBOzn4s3GDUv3c5oJD',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6gBFPUFcJLzWGx4lenP6h2',
#   'song_name': 'goosebumps',
#   'duration_ms': 243836,
#   'url': 'https://open.spotify.com/track/6gBFPUFcJLzWGx4lenP6h2',
#   'popularity': 86,
#   'song_added': '2017-07-18T12:40:41Z',
#   'album_id': '42WVQWuf1teDysXiOupIZt',
#   'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'song_id': '50kpGaPAhYJ3sGmk6vplg0',
#   'song_name': 'Love Yourself',
#   'duration_ms': 233720,
#   'url': 'https://open.spotify.com/track/50kpGaPAhYJ3sGmk6vplg0',
#   'popularity': 84,
#   'song_added': '2015-12-11T07:49:12Z',
#   'album_id': '6Fr2rQkZ383FcMqFyT7yPr',
#   'artist_id': '1uNFoZAHBGtllmzznpCI3s'},
#  {'song_id': '3AJwUDP919kvQ9QcozQPxg',
#   'song_name': 'Yellow',
#   'duration_ms': 266773,
#   'url': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg',
#   'popularity': 90,
#   'song_added': '2014-10-16T01:20:58Z',
#   'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU'},
#  {'song_id': '5VnDkUNyX6u5Sk0yZiP8XB',
#   'song_name': 'Thunder',
#   'duration_ms': 187146,
#   'url': 'https://open.spotify.com/track/5VnDkUNyX6u5Sk0yZiP8XB',
#   'popularity': 3,
#   'song_added': '2017-08-02T05:47:09Z',
#   'album_id': '51s30K7a36ORx6AAaPBRRY',
#   'artist_id': '53XhwfbYqKCa1cC15pYq2q'},
#  {'song_id': '3U4isOIWM3VvDubwSI3y7a',
#   'song_name': 'All of Me',
#   'duration_ms': 269560,
#   'url': 'https://open.spotify.com/track/3U4isOIWM3VvDubwSI3y7a',
#   'popularity': 86,
#   'song_added': '2014-10-22T06:45:29Z',
#   'album_id': '4OTAx9un4e6NfoHuVRiOrC',
#   'artist_id': '5y2Xq6xcjJb2jVM54GHK3t'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'duration_ms': 178426,
#   'url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'popularity': 88,
#   'song_added': '2023-07-28T00:33:20Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '4QRZirU4s1f30iDHzuKncj',
#   'song_name': 'Wake Me Up',
#   'duration_ms': 249693,
#   'url': 'https://open.spotify.com/track/4QRZirU4s1f30iDHzuKncj',
#   'popularity': 48,
#   'song_added': '2013-12-08T14:46:30Z',
#   'album_id': '37qAVEAZSyRTVFvVRHcwOa',
#   'artist_id': '1vCWHaC5f2uS3yhpwWbIA6'},
#  {'song_id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'song_name': 'Die For You',
#   'duration_ms': 260253,
#   'url': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3',
#   'popularity': 85,
#   'song_added': '2022-11-23T01:05:12Z',
#   'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '25khomWgBVamSdKw7hzm3l',
#   'song_name': 'The Hills',
#   'duration_ms': 242253,
#   'url': 'https://open.spotify.com/track/25khomWgBVamSdKw7hzm3l',
#   'popularity': 1,
#   'song_added': '2015-09-21T03:22:27Z',
#   'album_id': '28ZKQMoNBB0etKXZ97G2SN',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '3CRDbSIZ4r5MsZ0YwxuEkn',
#   'song_name': 'Stressed Out',
#   'duration_ms': 202333,
#   'url': 'https://open.spotify.com/track/3CRDbSIZ4r5MsZ0YwxuEkn',
#   'popularity': 84,
#   'song_added': '2016-05-16T06:17:56Z',
#   'album_id': '3cQO7jp5S9qLBoIVtbkSM1',
#   'artist_id': '3YQKmKGau1PzlVlkL1iodx'},
#  {'song_id': '3LlAyCYU26dvFZBDUIMb7a',
#   'song_name': 'Demons',
#   'duration_ms': 175200,
#   'url': 'https://open.spotify.com/track/3LlAyCYU26dvFZBDUIMb7a',
#   'popularity': 73,
#   'song_added': '2013-12-12T22:48:43Z',
#   'album_id': '6htgf3qv7vGcsdxLCDxKp8',
#   'artist_id': '53XhwfbYqKCa1cC15pYq2q'},
#  {'song_id': '62vpWI1CHwFy7tMIcSStl8',
#   'song_name': 'No Role Modelz',
#   'duration_ms': 292986,
#   'url': 'https://open.spotify.com/track/62vpWI1CHwFy7tMIcSStl8',
#   'popularity': 9,
#   'song_added': '2016-11-10T18:08:13Z',
#   'album_id': '7viNUmZZ8ztn2UB4XB3jIL',
#   'artist_id': '6l3HvQ5sa6mXTsMTB19rO5'},
#  {'song_id': '6GmUVqe73u5YRfUUynZK6I',
#   'song_name': 'Let Her Go',
#   'duration_ms': 252733,
#   'url': 'https://open.spotify.com/track/6GmUVqe73u5YRfUUynZK6I',
#   'popularity': 4,
#   'song_added': '2013-12-08T14:47:50Z',
#   'album_id': '2sRnJq6dfXdqhIflBk0ve1',
#   'artist_id': '0gadJ2b9A4SKsB1RFkBb66'},
#  {'song_id': '6ocbgoVGwYJhOv1GgI9NsF',
#   'song_name': '7 rings',
#   'duration_ms': 178626,
#   'url': 'https://open.spotify.com/track/6ocbgoVGwYJhOv1GgI9NsF',
#   'popularity': 82,
#   'song_added': '2020-04-15T05:37:20Z',
#   'album_id': '2fYhqwDWXjbpjaIJPEfKFw',
#   'artist_id': '66CXWjxzNUsdJxJ2JdwvnR'},
#  {'song_id': '7KXjTSCq5nL1LoYtL7XAwS',
#   'song_name': 'HUMBLE.',
#   'duration_ms': 177000,
#   'url': 'https://open.spotify.com/track/7KXjTSCq5nL1LoYtL7XAwS',
#   'popularity': 88,
#   'song_added': '2017-06-01T03:38:04Z',
#   'album_id': '4eLPsYPBmXABThSJ821sqY',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '7oK9VyNzrYvRFo7nQEYkWN',
#   'song_name': 'Mr. Brightside',
#   'duration_ms': 222586,
#   'url': 'https://open.spotify.com/track/7oK9VyNzrYvRFo7nQEYkWN',
#   'popularity': 14,
#   'song_added': '2014-05-03T23:16:35Z',
#   'album_id': '4undIeGmofnAYKhnDclN1w',
#   'artist_id': '0C0XlULifJtAgn6ZNCW2eu'},
#  {'song_id': '1mea3bSkSGXuIRvnydlB5b',
#   'song_name': 'Viva La Vida',
#   'duration_ms': 242373,
#   'url': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b',
#   'popularity': 87,
#   'song_added': '2014-03-03T01:33:24Z',
#   'album_id': '1CEODgTmTwLyabvwd7HBty',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU'},
#  {'song_id': '5Z01UMMf7V1o0MzF86s6WJ',
#   'song_name': 'Lose Yourself',
#   'duration_ms': 326466,
#   'url': 'https://open.spotify.com/track/5Z01UMMf7V1o0MzF86s6WJ',
#   'popularity': 78,
#   'song_added': '2014-03-02T07:02:09Z',
#   'album_id': '5qENHeCSlwWpEzb25peRmQ',
#   'artist_id': '7dGJo4pcD2V6oG8kP0tJRR'},
#  {'song_id': '3jfr0TF6DQcOLat8gGn7E2',
#   'song_name': 'Do I Wanna Know?',
#   'duration_ms': 272394,
#   'url': 'https://open.spotify.com/track/3jfr0TF6DQcOLat8gGn7E2',
#   'popularity': 2,
#   'song_added': '2014-05-06T11:29:14Z',
#   'album_id': '5bU1XKYxHhEwukllT20xtk',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '7lQ8MOhq6IN2w8EYcFNSUk',
#   'song_name': 'Without Me',
#   'duration_ms': 290320,
#   'url': 'https://open.spotify.com/track/7lQ8MOhq6IN2w8EYcFNSUk',
#   'popularity': 87,
#   'song_added': '2019-11-01T04:46:38Z',
#   'album_id': '2cWBwpqMsDJC1ZUwz813lo',
#   'artist_id': '7dGJo4pcD2V6oG8kP0tJRR'},
#  {'song_id': '7ef4DlsgrMEH11cDZd32M6',
#   'song_name': 'One Kiss (with Dua Lipa)',
#   'duration_ms': 214846,
#   'url': 'https://open.spotify.com/track/7ef4DlsgrMEH11cDZd32M6',
#   'popularity': 79,
#   'song_added': '2018-05-06T17:44:56Z',
#   'album_id': '7GEzhoTiqcPYkOprWQu581',
#   'artist_id': '7CajNmpbOovFoOoasH2HaY'},
#  {'song_id': '5wANPM4fQCJwkGd4rN57mH',
#   'song_name': 'drivers license',
#   'duration_ms': 242013,
#   'url': 'https://open.spotify.com/track/5wANPM4fQCJwkGd4rN57mH',
#   'popularity': 84,
#   'song_added': '2022-01-05T20:15:25Z',
#   'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '3ee8Jmje8o58CHK66QrVC2',
#   'song_name': 'SAD!',
#   'duration_ms': 166605,
#   'url': 'https://open.spotify.com/track/3ee8Jmje8o58CHK66QrVC2',
#   'popularity': 79,
#   'song_added': '2018-12-07T01:40:56Z',
#   'album_id': '2Ti79nwTsont5ZHfdxIzAm',
#   'artist_id': '15UsOTVnJzReFVN1VCnxy4'},
#  {'song_id': '1rtDwblY1CJ9i490fMzJnc',
#   'song_name': 'Treat You Better',
#   'duration_ms': 187973,
#   'url': 'https://open.spotify.com/track/1rtDwblY1CJ9i490fMzJnc',
#   'popularity': 0,
#   'song_added': '2016-09-28T02:53:59Z',
#   'album_id': '2AJaA0is5qbaqFy77tPl7B',
#   'artist_id': '7n2wHs1TKAczGzO7Dd2rGr'},
#  {'song_id': '0nJW01T7XtvILxQgC5J7Wh',
#   'song_name': 'When I Was Your Man',
#   'duration_ms': 213826,
#   'url': 'https://open.spotify.com/track/0nJW01T7XtvILxQgC5J7Wh',
#   'popularity': 88,
#   'song_added': '2013-12-08T15:15:45Z',
#   'album_id': '58ufpQsJ1DS5kq4hhzQDiI',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C'},
#  {'song_id': '4ZtFanR9U6ndgddUvNcjcG',
#   'song_name': 'good 4 u',
#   'duration_ms': 178146,
#   'url': 'https://open.spotify.com/track/4ZtFanR9U6ndgddUvNcjcG',
#   'popularity': 82,
#   'song_added': '2021-08-23T21:42:38Z',
#   'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '7m9OqQk4RVRkw9JJdeAw96',
#   'song_name': 'Jocelyn Flores',
#   'duration_ms': 119133,
#   'url': 'https://open.spotify.com/track/7m9OqQk4RVRkw9JJdeAw96',
#   'popularity': 80,
#   'song_added': '2019-02-08T07:19:30Z',
#   'album_id': '5VdyJkLe3yvOs0l4xXbWp0',
#   'artist_id': '15UsOTVnJzReFVN1VCnxy4'},
#  {'song_id': '7BqBn9nzAq8spo5e7cZ0dJ',
#   'song_name': 'Just the Way You Are',
#   'duration_ms': 220734,
#   'url': 'https://open.spotify.com/track/7BqBn9nzAq8spo5e7cZ0dJ',
#   'popularity': 87,
#   'song_added': '2019-11-01T05:12:04Z',
#   'album_id': '1uyf3l2d4XYwiEqAb7t7fX',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C'},
#  {'song_id': '0lYBSQXN6rCTvUZvg9S0lU',
#   'song_name': 'Let Me Love You',
#   'duration_ms': 205946,
#   'url': 'https://open.spotify.com/track/0lYBSQXN6rCTvUZvg9S0lU',
#   'popularity': 85,
#   'song_added': '2016-09-28T02:56:20Z',
#   'album_id': '02sEJTj1sye1JaqxqpcSCp',
#   'artist_id': '540vIaP2JwjQb9dm3aArA4'},
#  {'song_id': '2dpaYNEQHiRxtZbfNsse99',
#   'song_name': 'Happier',
#   'duration_ms': 214289,
#   'url': 'https://open.spotify.com/track/2dpaYNEQHiRxtZbfNsse99',
#   'popularity': 11,
#   'song_added': '2018-12-07T01:41:58Z',
#   'album_id': '78EicdHZr5XBWD7llEZ1Jh',
#   'artist_id': '64KEffDW9EtZ1y2vBYgq8T'},
#  {'song_id': '3B54sVLJ402zGa6Xm4YGNe',
#   'song_name': 'Unforgettable',
#   'duration_ms': 233901,
#   'url': 'https://open.spotify.com/track/3B54sVLJ402zGa6Xm4YGNe',
#   'popularity': 85,
#   'song_added': '2020-03-28T02:36:54Z',
#   'album_id': '4c2p3TdN7NcQfCXyueCNnC',
#   'artist_id': '6vXTefBL93Dj5IqAWq6OTv'},
#  {'song_id': '2xLMifQCjDGFmkHkpNLD9h',
#   'song_name': 'SICKO MODE',
#   'duration_ms': 312820,
#   'url': 'https://open.spotify.com/track/2xLMifQCjDGFmkHkpNLD9h',
#   'popularity': 82,
#   'song_added': '2019-11-01T04:19:45Z',
#   'album_id': '41GuZcammIkupMPKH2OJ6I',
#   'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'song_id': '7GX5flRQZVHRAGd6B4TmDO',
#   'song_name': 'XO Tour Llif3',
#   'duration_ms': 182706,
#   'url': 'https://open.spotify.com/track/7GX5flRQZVHRAGd6B4TmDO',
#   'popularity': 79,
#   'song_added': '2019-11-08T23:23:28Z',
#   'album_id': '733e1ZfktLSwj96X5rsMeE',
#   'artist_id': '4O15NlyKLIASxsJ0PrXPfz'},
#  {'song_id': '4DHcnVTT87F0zZhRPYmZ3B',
#   'song_name': 'Flowers',
#   'duration_ms': 200600,
#   'url': 'https://open.spotify.com/track/4DHcnVTT87F0zZhRPYmZ3B',
#   'popularity': 9,
#   'song_added': '2023-05-07T07:31:21Z',
#   'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '0KKkJNfGyhkQ5aFogxQAPU',
#   'song_name': "That's What I Like",
#   'duration_ms': 206693,
#   'url': 'https://open.spotify.com/track/0KKkJNfGyhkQ5aFogxQAPU',
#   'popularity': 88,
#   'song_added': '2017-06-01T03:39:42Z',
#   'album_id': '4PgleR09JVnm3zY1fW3XBA',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C'},
#  {'song_id': '1JSTJqkT5qHq8MDJnJbRE1',
#   'song_name': 'Every Breath You Take',
#   'duration_ms': 253920,
#   'url': 'https://open.spotify.com/track/1JSTJqkT5qHq8MDJnJbRE1',
#   'popularity': 89,
#   'song_added': '2019-11-01T04:52:22Z',
#   'album_id': '5W9OT0a5iZlBr83a9WMKFY',
#   'artist_id': '5NGO30tJxFlKixkPSgXcFE'},
#  {'song_id': '60a0Rd6pjrkxjPbaKzXjfq',
#   'song_name': 'In the End',
#   'duration_ms': 216880,
#   'url': 'https://open.spotify.com/track/60a0Rd6pjrkxjPbaKzXjfq',
#   'popularity': 86,
#   'song_added': '2014-11-24T21:19:07Z',
#   'album_id': '6hPkbAV3ZXpGZBGUvL6jVM',
#   'artist_id': '6XyY86QOPPrYVGvF9ch6wz'},
#  {'song_id': '09CtPGIpYB4BrO8qb1RGsF',
#   'song_name': 'Sorry',
#   'duration_ms': 200786,
#   'url': 'https://open.spotify.com/track/09CtPGIpYB4BrO8qb1RGsF',
#   'popularity': 84,
#   'song_added': '2015-12-11T07:51:10Z',
#   'album_id': '6Fr2rQkZ383FcMqFyT7yPr',
#   'artist_id': '1uNFoZAHBGtllmzznpCI3s'},
#  {'song_id': '4vS8VaBwJJV5Ry7UFIQuoo',
#   'song_name': 'Lean On (feat. MØ & DJ Snake)',
#   'duration_ms': 176561,
#   'url': 'https://open.spotify.com/track/4vS8VaBwJJV5Ry7UFIQuoo',
#   'popularity': 1,
#   'song_added': '2015-07-18T18:18:21Z',
#   'album_id': '4DOcG4A40Wf3q2vPNGQwQg',
#   'artist_id': '738wLrAtLtCtFOLvQBXOXp'},
#  {'song_id': '2ekn2ttSfGqwhhate0LSR0',
#   'song_name': 'New Rules',
#   'duration_ms': 209320,
#   'url': 'https://open.spotify.com/track/2ekn2ttSfGqwhhate0LSR0',
#   'popularity': 79,
#   'song_added': '2017-09-06T05:26:11Z',
#   'album_id': '01sfgrNbnnPUEyz6GZYlt9',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '1qCdYQdkWvm4cYXAuOlbyc',
#   'song_name': 'Locked out of Heaven',
#   'duration_ms': 233478,
#   'url': 'https://open.spotify.com/track/1qCdYQdkWvm4cYXAuOlbyc',
#   'popularity': 45,
#   'song_added': '2013-12-08T14:50:36Z',
#   'album_id': '7KBjLhk3IM27k3ry4vBk3i',
#   'artist_id': '0du5cEVh5yTK9QJze8zA0C'},
#  {'song_id': '5nujrmhLynf4yMoMtj8AQF',
#   'song_name': 'Levitating (feat. DaBaby)',
#   'duration_ms': 203064,
#   'url': 'https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF',
#   'popularity': 80,
#   'song_added': '2022-01-13T08:59:31Z',
#   'album_id': '5lKlFlReHOLShQKyRv6AL9',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '7JJmb5XwzOO8jgpou264Ml',
#   'song_name': "There's Nothing Holdin' Me Back",
#   'duration_ms': 199440,
#   'url': 'https://open.spotify.com/track/7JJmb5XwzOO8jgpou264Ml',
#   'popularity': 85,
#   'song_added': '2017-07-07T01:34:13Z',
#   'album_id': '3wBabo4pmzsYjALMSKY7Iq',
#   'artist_id': '7n2wHs1TKAczGzO7Dd2rGr'},
#  {'song_id': '3VlbOrM6nYPprVvzBZllE5',
#   'song_name': 'Too Good At Goodbyes',
#   'duration_ms': 201000,
#   'url': 'https://open.spotify.com/track/3VlbOrM6nYPprVvzBZllE5',
#   'popularity': 1,
#   'song_added': '2019-11-01T02:19:59Z',
#   'album_id': '3XftSbguntyRTBQaGItmfK',
#   'artist_id': '2wY79sveU1sp5g7SokKOiI'},
#  {'song_id': '5Nm9ERjJZ5oyfXZTECKmRt',
#   'song_name': 'Stay With Me',
#   'duration_ms': 172723,
#   'url': 'https://open.spotify.com/track/5Nm9ERjJZ5oyfXZTECKmRt',
#   'popularity': 81,
#   'song_added': '2019-11-01T04:27:19Z',
#   'album_id': '08jWgM4vSkTose4blKBWov',
#   'artist_id': '2wY79sveU1sp5g7SokKOiI'},
#  {'song_id': '7rglLriMNBPAyuJOMGwi39',
#   'song_name': 'Cold Heart - PNAU Remix',
#   'duration_ms': 202735,
#   'url': 'https://open.spotify.com/track/7rglLriMNBPAyuJOMGwi39',
#   'popularity': 68,
#   'song_added': '2022-01-12T00:04:05Z',
#   'album_id': '7wHczdY0ek3FHnfVhk10om',
#   'artist_id': '3PhoLpVuITZKcymswpck5b'},
#  {'song_id': '1rfofaqEpACxVEHIZBJe6W',
#   'song_name': 'Havana (feat. Young Thug)',
#   'duration_ms': 217306,
#   'url': 'https://open.spotify.com/track/1rfofaqEpACxVEHIZBJe6W',
#   'popularity': 81,
#   'song_added': '2020-02-12T03:28:44Z',
#   'album_id': '2vD3zSQr8hNlg0obNel4TE',
#   'artist_id': '4nDoRrQiYLoBzwC5BhVJzF'},
#  {'song_id': '5ghIJDpPoe3CfHMGu71E6T',
#   'song_name': 'Smells Like Teen Spirit',
#   'duration_ms': 301920,
#   'url': 'https://open.spotify.com/track/5ghIJDpPoe3CfHMGu71E6T',
#   'popularity': 79,
#   'song_added': '2014-10-24T21:51:59Z',
#   'album_id': '2guirTSEqLizK7j9i1MTTZ',
#   'artist_id': '6olE6TJLqED3rqDCT0FyPh'},
#  {'song_id': '6FZDfxM3a3UCqtzo5pxSLZ',
#   'song_name': 'Without Me',
#   'duration_ms': 201660,
#   'url': 'https://open.spotify.com/track/6FZDfxM3a3UCqtzo5pxSLZ',
#   'popularity': 82,
#   'song_added': '2020-03-28T02:39:31Z',
#   'album_id': '68enXe5XcJdciSDAZr0Alr',
#   'artist_id': '26VFTg2z8YR0cCuwLzESi2'},
#  {'song_id': '5QO79kh1waicV47BqGRL3g',
#   'song_name': 'Save Your Tears',
#   'duration_ms': 215626,
#   'url': 'https://open.spotify.com/track/5QO79kh1waicV47BqGRL3g',
#   'popularity': 85,
#   'song_added': '2021-11-10T21:42:36Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '5wj4E6IsrVtn8IBJQOd0Cl',
#   'song_name': 'Wonderwall (Remastered)',
#   'duration_ms': 258732,
#   'url': 'https://open.spotify.com/track/5wj4E6IsrVtn8IBJQOd0Cl',
#   'popularity': 2,
#   'song_added': '2019-11-01T04:54:21Z',
#   'album_id': '6ozp33PI3p9AdddB6ZL3xQ',
#   'artist_id': '2DaxqgrOhkeH0fpeiQq2f4'},
#  {'song_id': '7hQJA50XrCWABAu5v6QZ4i',
#   'song_name': "Don't Stop Me Now - Remastered 2011",
#   'duration_ms': 209413,
#   'url': 'https://open.spotify.com/track/7hQJA50XrCWABAu5v6QZ4i',
#   'popularity': 74,
#   'song_added': '2019-02-08T06:53:19Z',
#   'album_id': '21HMAUrbbYSj9NiPPlGumy',
#   'artist_id': '1dfeR4HaWDbWqFHLkxsg1d'},
#  {'song_id': '4cktbXiXOapiLBMprHFErI',
#   'song_name': 'Memories',
#   'duration_ms': 189486,
#   'url': 'https://open.spotify.com/track/4cktbXiXOapiLBMprHFErI',
#   'popularity': 83,
#   'song_added': '2022-08-30T23:21:01Z',
#   'album_id': '1pCA38N6MkLlthXtAOvZTU',
#   'artist_id': '04gDigrS5kc9YWfZHwBETP'},
#  {'song_id': '4bHsxqR3GMrXTxEPLuK5ue',
#   'song_name': "Don't Stop Believin'",
#   'duration_ms': 250986,
#   'url': 'https://open.spotify.com/track/4bHsxqR3GMrXTxEPLuK5ue',
#   'popularity': 16,
#   'song_added': '2019-11-01T04:51:54Z',
#   'album_id': '43wpzak9OmQfrjyksuGwp0',
#   'artist_id': '0rvjqX7ttXeg3mTy8Xscbt'},
#  {'song_id': '32OlwWuMpZ6b0aN2RZOeMS',
#   'song_name': 'Uptown Funk (feat. Bruno Mars)',
#   'duration_ms': 269666,
#   'url': 'https://open.spotify.com/track/32OlwWuMpZ6b0aN2RZOeMS',
#   'popularity': 85,
#   'song_added': '2015-02-05T21:18:12Z',
#   'album_id': '3vLaOYCNCzngDf8QdBg2V1',
#   'artist_id': '3hv9jJF3adDNsBSIQDqcjp'},
#  {'song_id': '5Z9KJZvQzH6PFmb8SNkxuk',
#   'song_name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'duration_ms': 212352,
#   'url': 'https://open.spotify.com/track/5Z9KJZvQzH6PFmb8SNkxuk',
#   'popularity': 72,
#   'song_added': '2021-11-13T04:57:32Z',
#   'album_id': '6pOiDiuDQqrmo5DbG0ZubR',
#   'artist_id': '7jVv8c5Fj3E9VhNjxT4snq'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'duration_ms': 153946,
#   'url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 86,
#   'song_added': '2023-05-25T04:20:31Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '2WfaOiMkCvy7F5fcp2zZ8L',
#   'song_name': 'Take on Me',
#   'duration_ms': 225280,
#   'url': 'https://open.spotify.com/track/2WfaOiMkCvy7F5fcp2zZ8L',
#   'popularity': 85,
#   'song_added': '2019-11-01T04:52:37Z',
#   'album_id': '1ER3B6zev5JEAaqhnyyfbf',
#   'artist_id': '2jzc5TC5TVFLXQlBNiIUzE'},
#  {'song_id': '4MzXwWMhyBbmu6hOcLVD49',
#   'song_name': 'DÁKITI',
#   'duration_ms': 205090,
#   'url': 'https://open.spotify.com/track/4MzXwWMhyBbmu6hOcLVD49',
#   'popularity': 77,
#   'song_added': '2020-12-08T09:14:55Z',
#   'album_id': '2d9BCZeAAhiZWPpbX9aPCW',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '3a1lNhkSLSkpJE4MSHpDu9',
#   'song_name': 'Congratulations',
#   'duration_ms': 220293,
#   'url': 'https://open.spotify.com/track/3a1lNhkSLSkpJE4MSHpDu9',
#   'popularity': 79,
#   'song_added': '2017-06-01T03:46:40Z',
#   'album_id': '5s0rmjP8XOPhP6HhqOhuyC',
#   'artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '4xkOaSrkexMciUUogZKVTS',
#   'song_name': 'Till I Collapse',
#   'duration_ms': 297786,
#   'url': 'https://open.spotify.com/track/4xkOaSrkexMciUUogZKVTS',
#   'popularity': 83,
#   'song_added': '2014-10-16T08:01:27Z',
#   'album_id': '2cWBwpqMsDJC1ZUwz813lo',
#   'artist_id': '7dGJo4pcD2V6oG8kP0tJRR'},
#  {'song_id': '4kflIGfjdZJW4ot2ioixTB',
#   'song_name': 'Someone Like You',
#   'duration_ms': 285040,
#   'url': 'https://open.spotify.com/track/4kflIGfjdZJW4ot2ioixTB',
#   'popularity': 4,
#   'song_added': '2014-09-02T04:28:50Z',
#   'album_id': '1azUkThwd2HfUDdeNeT147',
#   'artist_id': '4dpARuHxo51G3z768sgnrY'},
#  {'song_id': '1MtUq6Wp1eQ8PC6BbPCj8P',
#   'song_name': 'I Took A Pill In Ibiza - Seeb Remix',
#   'duration_ms': 197933,
#   'url': 'https://open.spotify.com/track/1MtUq6Wp1eQ8PC6BbPCj8P',
#   'popularity': 65,
#   'song_added': '2016-06-27T04:41:09Z',
#   'album_id': '1Tz3Ai1guEFf4hV3d9i17K',
#   'artist_id': '2KsP6tYLJlTBvSUxnwlVWa'},
#  {'song_id': '75JFxkI2RXiU7L9VXzMkle',
#   'song_name': 'The Scientist',
#   'duration_ms': 309600,
#   'url': 'https://open.spotify.com/track/75JFxkI2RXiU7L9VXzMkle',
#   'popularity': 88,
#   'song_added': '2014-05-03T23:15:27Z',
#   'album_id': '0RHX9XECH8IVI3LNgWDpmQ',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                     name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                              After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                               ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70  Divinely Uninspired To A Hellish Extent
# 3  5r36AJ6VOJtp00oxSkBZ5h                            Harry's House
# 4  2ODvWsOgouMbaA5xf0RkJe                                  Starboy
#
#   release_date  total_tracks  \
# 0   2020-03-20            14
# 1   2017-03-03            16
# 2   2019-05-17            12
# 3   2022-05-20            13
# 4   2016-11-25            18
#
#                                                  url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3  https://open.spotify.com/album/5r36AJ6VOJtp00o...
# 4  https://open.spotify.com/album/2ODvWsOgouMbaA5...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df
# Out:
#                   artist_id    artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2    4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 3    6KImCVD70vtIoJWnq6nGn3   Harry Styles
# 5    4tZwfgrHOc3mvqYlEYSvVi      Daft Punk
# ..                      ...            ...
# 123  0VRj0yCOv2FXJNP47XQnx5          Quavo
# 125  1Oa0bMld0A3u5OTYfMzp5h      Nate Dogg
# 126  4dpARuHxo51G3z768sgnrY          Adele
# 127  2KsP6tYLJlTBvSUxnwlVWa    Mike Posner
# 128  5iNrZmtVMtYev5M9yoWpEq           Seeb
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1    https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2    https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3    https://api.spotify.com/v1/artists/6KImCVD70vt...
# 5    https://api.spotify.com/v1/artists/4tZwfgrHOc3...
# ..                                                 ...
# 123  https://api.spotify.com/v1/artists/0VRj0yCOv2F...
# 125  https://api.spotify.com/v1/artists/1Oa0bMld0A3...
# 126  https://api.spotify.com/v1/artists/4dpARuHxo51...
# 127  https://api.spotify.com/v1/artists/2KsP6tYLJlT...
# 128  https://api.spotify.com/v1/artists/5iNrZmtVMtY...
#
# [86 rows x 3 columns]

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights       200040
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You       233712
# 2  7qEHsqek33rTcFNT9PFqLf  Someone You Loved       182160
# 3  4Dvkj6JhhA12EX05fT7y2e          As It Was       167303
# 4  7MXVkk9YMctZqd1Srtv4MB            Starboy       230453
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0VjIjW4GlUZAMYd...          88
# 1  https://open.spotify.com/track/7qiZfU4dY1lWllz...          87
# 2  https://open.spotify.com/track/7qEHsqek33rTcFN...          85
# 3  https://open.spotify.com/track/4Dvkj6JhhA12EX0...          87
# 4  https://open.spotify.com/track/7MXVkk9YMctZqd1...          88
#
#              song_added                album_id               artist_id
# 0  2020-03-20T04:54:59Z  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  2017-06-09T00:39:52Z  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# 2  2019-08-31T17:45:01Z  5658aM19fA3JVwTK6eQX70  4GNC7GD6oZMSxPGyXy4MNB
# 3  2022-08-30T23:21:01Z  5r36AJ6VOJtp00oxSkBZ5h  6KImCVD70vtIoJWnq6nGn3
# 4  2017-06-09T00:44:54Z  2ODvWsOgouMbaA5xf0RkJe  1Xyo4u8uXC1ZmMpatF05PJ

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 3  6KImCVD70vtIoJWnq6nGn3   Harry Styles
# 5  4tZwfgrHOc3mvqYlEYSvVi      Daft Punk
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3  https://api.spotify.com/v1/artists/6KImCVD70vt...
# 5  https://api.spotify.com/v1/artists/4tZwfgrHOc3...

# %%
album_df.head()
# Out:
#                  album_id                                     name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                              After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                               ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70  Divinely Uninspired To A Hellish Extent
# 3  5r36AJ6VOJtp00oxSkBZ5h                            Harry's House
# 4  2ODvWsOgouMbaA5xf0RkJe                                  Starboy
#
#   release_date  total_tracks  \
# 0   2020-03-20            14
# 1   2017-03-03            16
# 2   2019-05-17            12
# 3   2022-05-20            13
# 4   2016-11-25            18
#
#                                                  url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3  https://open.spotify.com/album/5r36AJ6VOJtp00o...
# 4  https://open.spotify.com/album/2ODvWsOgouMbaA5...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      93 non-null     object
#  1   name          93 non-null     object
#  2   release_date  92 non-null     datetime64[ns]
#  3   total_tracks  93 non-null     int64
#  4   url           93 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.4+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
